# %%
import pandas as pd

# %%
d1 = pd.read_json('products_sample_01.json',encoding='UTF-8')
d2 = pd.read_json('products_sample_02.json',encoding='UTF-8')

# %%
sample_data = pd.read_csv('export_catalog_product_20231221_083450.csv')

# %%
sample_data.head()
# Out:
#        sku  store_view_code attribute_set_code product_type        categories  \
# 0  1185626              NaN            Default      virtual  Default Category
#
#   product_websites             name  description  \
# 0             base  Steam Distiller          NaN
#
#                                    short_description  weight  ...  \
# 0  Produces 1 gallon of 100% steam distilled wate...     NaN  ...
#
#    bundle_sku_type bundle_price_view bundle_weight_type  bundle_values  \
# 0              NaN               NaN                NaN            NaN
#
#    bundle_shipment_type  associated_skus  downloadable_links  \
# 0                   NaN              NaN                 NaN
#
#   downloadable_samples configurable_variations  configurable_variation_labels
# 0                  NaN                     NaN                            NaN
#
# [1 rows x 89 columns]

# %%
d1.head()
# Out:
#        _id                                         meta_title  \
# 0  1185626   Tuttnauer USA DS1000 - McKesson Medical-Surgical
# 1  1177583  HoMedics USA LLC AP-T20WT - McKesson Medical-S...
# 2  1177584  HoMedics USA LLC AP-PET35-WT - McKesson Medica...
# 3  1002865  Auxo Medical AM-WC-PCS-20 - McKesson Medical-S...
# 4  1181297  HoMedics USA LLC AP-T30WT - McKesson Medical-S...
#
#                                           page_title  \
# 0   Tuttnauer USA DS1000 - McKesson Medical-Surgical
# 1  HoMedics USA LLC AP-T20WT - McKesson Medical-S...
# 2  HoMedics USA LLC AP-PET35-WT - McKesson Medica...
# 3  Auxo Medical AM-WC-PCS-20 - McKesson Medical-S...
# 4  HoMedics USA LLC AP-T30WT - McKesson Medical-S...
#
#                                     meta_description  views times_used  \
# 0  DS1000 Steam Distiller 1 gal. 9-3/4 X 15 X 15-...      0
# 1  HoMedics® TotalClean® 5-in-1 UV Air Purifier S...      0
# 2  HoMedics® TotalClean® PetPlus 5-In-1 Air Purif...      0
# ...

# %%
data1= pd.read_csv('d1.csv')

# %%
new_Data = pd.DataFrame(columns=sample_data.columns)

# %%
new_Data
# Out:
# Empty DataFrame
# ...

# %%
new_Data['sku'] = d1['_id']
new_Data['attribute_set_code'] = 'Default'
new_Data['product_type'] = 'virtual'
new_Data['categories'] = 'Default Category'
new_Data['product_websites'] = 'base'

# %%
new_Data
# Out:
#          sku store_view_code attribute_set_code product_type  \
# 0    1185626             NaN            Default      virtual
# 1    1177583             NaN            Default      virtual
# 2    1177584             NaN            Default      virtual
# 3    1002865             NaN            Default      virtual
# 4    1181297             NaN            Default      virtual
# ..       ...             ...                ...          ...
# 495   774273             NaN            Default      virtual
# 496   774276             NaN            Default      virtual
# 497   142270             NaN            Default      virtual
# 498  1128140             NaN            Default      virtual
# 499  1010853             NaN            Default      virtual
#
#            categories product_websites name description short_description  \
# 0    Default Category             base  NaN         NaN               NaN
# 1    Default Category             base  NaN         NaN               NaN
# ...

# %%
sample_data.head()
# Out:
#        sku  store_view_code attribute_set_code product_type        categories  \
# 0  1185626              NaN            Default      virtual  Default Category
#
#   product_websites             name  description  \
# 0             base  Steam Distiller          NaN
#
#                                    short_description  weight  ...  \
# 0  Produces 1 gallon of 100% steam distilled wate...     NaN  ...
#
#    bundle_sku_type bundle_price_view bundle_weight_type  bundle_values  \
# 0              NaN               NaN                NaN            NaN
#
#    bundle_shipment_type  associated_skus  downloadable_links  \
# 0                   NaN              NaN                 NaN
#
#   downloadable_samples configurable_variations  configurable_variation_labels
# 0                  NaN                     NaN                            NaN
#
# [1 rows x 89 columns]

# %%
name = []
# manufacturer=[]
for i in d1['schema']:
    k1=dict(i)['name']
#     k2=dict(i)['manufacturer']
    name.append(k1)
#     manufacturer.append(k2)

# %%
new_Data['name'] = name

# %%
new_Data['tax_class_name'] = 'Taxable Goods'
new_Data['visibility'] = 'Not Visible Individually'
new_Data['price']= 0
new_Data['meta_title']=d1['meta_title']
new_Data['meta_description'] = d1['meta_description']
new_Data['created_at'] = d1['created_at']
new_Data['new_from_date'] = '12/21/23'
new_Data['display_product_options_in'] = 'Block after Info Column'
new_Data['gift_message_available'] = 'Use config'
new_Data['page_layout'] = 'Product -- Full Width'
new_Data['msrp_display_actual_price_type'] = 'Use config'
new_Data['qty'] = 0
new_Data['out_of_stock_qty'] = 0
new_Data['use_config_min_qty'] = 1
new_Data['is_qty_decimal'] = 0
new_Data['allow_backorders'] = 0
new_Data['use_config_backorders']=1
new_Data['min_cart_qty'] = 1
new_Data['use_config_min_sale_qty'] = 1
new_Data['max_cart_qty'] = 10000
new_Data['use_config_max_sale_qty'] = 1
new_Data['is_in_stock'] = 0
new_Data['notify_on_stock_below'] = 1
new_Data['use_config_notify_stock_qty'] = 1
new_Data['manage_stock'] = 1
new_Data['use_config_manage_stock'] = 1
new_Data['use_config_qty_increments'] = 1
new_Data['qty_increments'] = 1
new_Data['use_config_enable_qty_inc'] = 1
new_Data['enable_qty_increments'] = 0
new_Data['is_decimal_divided'] = 0
new_Data['website_id'] = 0

# %%
new_Data
# Out:
#          sku store_view_code attribute_set_code product_type  \
# 0    1185626             NaN            Default      virtual
# 1    1177583             NaN            Default      virtual
# 2    1177584             NaN            Default      virtual
# 3    1002865             NaN            Default      virtual
# 4    1181297             NaN            Default      virtual
# ..       ...             ...                ...          ...
# 495   774273             NaN            Default      virtual
# 496   774276             NaN            Default      virtual
# 497   142270             NaN            Default      virtual
# 498  1128140             NaN            Default      virtual
# 499  1010853             NaN            Default      virtual
#
#            categories product_websites                     name description  \
# 0    Default Category             base          Steam Distiller         NaN
# 1    Default Category             base             Air Purifier         NaN
# ...

# %%
import textwrap
features = []
for i,v in enumerate(d1['product-features']):
    features.append([textwrap.fill(line,width=60) for line in v])

# %%
new_Data['short_description'] = features

# %%
new_Data
# Out:
#          sku store_view_code attribute_set_code product_type  \
# 0    1185626             NaN            Default      virtual
# 1    1177583             NaN            Default      virtual
# 2    1177584             NaN            Default      virtual
# 3    1002865             NaN            Default      virtual
# 4    1181297             NaN            Default      virtual
# ..       ...             ...                ...          ...
# 495   774273             NaN            Default      virtual
# 496   774276             NaN            Default      virtual
# 497   142270             NaN            Default      virtual
# 498  1128140             NaN            Default      virtual
# 499  1010853             NaN            Default      virtual
#
#            categories product_websites                     name description  \
# 0    Default Category             base          Steam Distiller         NaN
# 1    Default Category             base             Air Purifier         NaN
# ...

# %%
new_Data.to_csv(r'C:\Users\devan\Downloads\one-stop-medical-shop-main\one-stop-medical-shop-main\datasets\products.csv',index=False,encoding='UTF-8')

# %%
d2.head()
# Out:
#                 _id                                            product  \
# 0  MDPRJHG617388BLA  {'productId': 'Z05-PF175855', 'details': {'lon...
# 1  MDPBKCCRMOPCART1  {'productId': 'Z05-PF267058', 'details': {'lon...
# 2       MDPMPHMC1TW  {'productId': 'Z05-PF08011', 'details': {'long...
# 3       MDPCCJ188WY  {'productId': 'Z05-PF00956', 'details': {'long...
# 4   MDPWXS619000BLA  {'productId': 'Z05-PF165068', 'details': {'dis...
#
#         material                                            details  \
# 0  RJHG617388BLA  {'isLatexFree': True, 'mfrProdNum': 'FG617388B...
# 1  BKCCRMOPCART1  {'mfrProdNum': 'MCRMOPCART1', 'salesUOM': 'EA'...
# 2       MPHMC1TW  {'isLatexFree': True, 'mfrProdNum': 'MPHMC1TW'...
# 3       CCJ188WY  {'isLatexFree': True, 'mfrProdNum': '188WY', '...
# 4   WXS619000BLA  {'isLatexFree': True, 'mfrProdNum': '88RMFG619...
#
#                                                media  \
# 0  [{'type': 'imagePrimary', 'url': 'https://www....
# ...

# %%
prod_2 = new_Data.copy()

# %%
prod_2
# Out:
#          sku store_view_code attribute_set_code product_type  \
# 0    1185626             NaN            Default      virtual
# 1    1177583             NaN            Default      virtual
# 2    1177584             NaN            Default      virtual
# 3    1002865             NaN            Default      virtual
# 4    1181297             NaN            Default      virtual
# ..       ...             ...                ...          ...
# 495   774273             NaN            Default      virtual
# 496   774276             NaN            Default      virtual
# 497   142270             NaN            Default      virtual
# 498  1128140             NaN            Default      virtual
# 499  1010853             NaN            Default      virtual
#
#            categories product_websites                     name description  \
# 0    Default Category             base          Steam Distiller         NaN
# 1    Default Category             base             Air Purifier         NaN
# ...

# %%
name_p2 = []
description_p2 = []
manufact_p2 = []

prod_2['sku'] = d2['_id']

# %%
for i in d2['product']:
    p = str(i['details']['displayName'])
    m = str(i['details']['manufacturer'])
    name_p2.append(p)
    manufact_p2.append(m)
description_p2 = []

for product_info in d2.get('product', []):
    details = product_info.get('details', {})
    long_description = details.get('longDescription', '')
    description_p2.append(str(long_description))

# %%
d2.isna().sum()
# Out:
# _id                   0
# product               0
# material              0
# details               0
# media                 0
# specifications        0
# packagingDetails      0
# documents           381
# dtype: int64

# %%
name_p2
# Out:
# ['Cleaning Cart with Zippered Vinyl Bag',
#  'Cleanroom Mop Carts with Buckets',
#  'MIYO Housekeeping Carts',
#  'Janitor Cart',
#  'Housekeeping Carts by Rubbermaid',
#  'High-Capacity Janitorial Cart Executive Waste Covers',
#  'FitRight Double Up Thin Incontinence Booster Pads',
#  'AliMed MRI Custodial Carts',
#  'FitRight Double Up Thin Incontinence Booster Pads',
#  'FitRight Double Up Thin Incontinence Booster Pads',
#  'MIYO Housekeeping Carts',
#  'MIYO Housekeeping Carts',
#  'FitRight Active Guards for Men',
#  'Plastic Cleaning Carts',
#  'Vyaire AirLife ETCO2 Sampling Cannulas',
#  'FitRight Active Guards for Men',
#  'Alpha Foldable Bag Holders Parts',
#  'EnCompass Modular Cleaning Station',
#  'Executive High-Security Cleaning Carts',
#  'Executive Janitorial Cleaning Carts',
#  'EquoDose Charging System',
#  'MIYO Housekeeping Carts',
#  'Alpha Foldable Bag Holders Parts',
#  'MIYO Housekeeping Carts',
#  'Vyaire AirLife ETCO2 Sampling Cannulas',
# ...

# %%
manufact_p2
# Out:
# ['RUBBERMAID',
#  'BERKSHIRE CORPORATION',
#  'Various Manufacturers / Suppliers',
#  'CONTINENTAL COMMERCIAL PRODUCTS LLC',
#  'RUBBERMAID',
#  'RUBBERMAID',
#  'MEDLINE',
#  'ALIMED',
#  'MEDLINE',
#  'MEDLINE',
#  'Various Manufacturers / Suppliers',
#  'Various Manufacturers / Suppliers',
#  'MEDLINE',
#  'RUBBERMAID',
#  'VYAIRE MEDICAL, INC.',
#  'MEDLINE',
#  'FILMOP',
#  'ECOLAB',
#  'RUBBERMAID',
#  'RUBBERMAID',
#  'FILMOP',
#  'Various Manufacturers / Suppliers',
#  'FILMOP',
#  'Various Manufacturers / Suppliers',
#  'VYAIRE MEDICAL, INC.',
#  'Various Manufacturers / Suppliers',
#  'KIMBERLY-CLARK CORPORATION',
#  'SUNCAST CORPORATION',
#  'SUNMED',
#  'ROYAL PHILIPS',
#  'RUBBERMAID',
#  'Various Manufacturers / Suppliers',
#  'VYAIRE MEDICAL, INC.',
#  'VYAIRE MEDICAL, INC.',
#  'RUBBERMAID',
#  'MEDLINE',
#  'FILMOP',
#  'FIRST QUALITY PRODUCTS',
#  'SUNCAST CORPORATION',
#  'RUBBERMAID',
#  'FIRST QUALITY PRODUCTS',
#  'RUBBERMAID',
# ...

# %%
new_Data
# Out:
#          sku store_view_code attribute_set_code product_type  \
# 0    1185626             NaN            Default      virtual
# 1    1177583             NaN            Default      virtual
# 2    1177584             NaN            Default      virtual
# 3    1002865             NaN            Default      virtual
# 4    1181297             NaN            Default      virtual
# ..       ...             ...                ...          ...
# 495   774273             NaN            Default      virtual
# 496   774276             NaN            Default      virtual
# 497   142270             NaN            Default      virtual
# 498  1128140             NaN            Default      virtual
# 499  1010853             NaN            Default      virtual
#
#            categories product_websites                     name description  \
# 0    Default Category             base          Steam Distiller         NaN
# 1    Default Category             base             Air Purifier         NaN
# ...

# %%
prod_2['name'] = name_p2

# %%
prod_2['short_description'] = description_p2

# %%
prod_2.to_csv(r'C:\Users\devan\Downloads\one-stop-medical-shop-main\one-stop-medical-shop-main\datasets\product2.csv',index=False,encoding='UTF-8')

# %%
product_2_for_neo4j = prod_2.copy()

# %%
product_2_for_neo4j['manufacturer'] = manufact_p2

# %%
product_1_for_neo4j = new_Data.copy()
manufacturer=[]
for i in d1['schema']:
    k2=dict(i)['manufacturer']
    manufacturer.append(k2)
product_1_for_neo4j['manufacturer'] = manufacturer

# %%
product_1_for_neo4j['manufacturer']
product_2_for_neo4j['manufacturer']
product_1_for_neo4j.to_csv(r'C:\Users\devan\Downloads\one-stop-medical-shop-main\one-stop-medical-shop-main\datasets\prod1_neo4j.csv',index=False,encoding='UTF-8')
product_2_for_neo4j.to_csv(r'C:\Users\devan\Downloads\one-stop-medical-shop-main\one-stop-medical-shop-main\datasets\prod2_neo4j.csv',index=False,encoding='UTF-8')

# %%
final_product = merged_df = pd.concat([product_1_for_neo4j, product_2_for_neo4j],axis=0)

# %%
len(product_1_for_neo4j.columns)
# Out:
# 90

# %%
len(product_2_for_neo4j.columns)
# Out:
# 90

# %%
final_product.to_csv(r'C:\Users\devan\Downloads\one-stop-medical-shop-main\one-stop-medical-shop-main\datasets\final_product.csv',index=False,encoding='UTF-8')
